# %% [markdown]
# # This program generate benchmark ontology for testing NOWL
#
# The benchmark is inspired by [1]. However, the coverage matrix is creating not using every OWL 2.0 construct but a list of constraints. The syntax for expressing a constraint may need multiple OWL 2.0 construct.
#
# List of constraints (class expression) and OWL entities used are:
#
# | Type of element          |   Available* |
# | -------------------------| -------- |
# | Ontology                 | ✕ |
# | Annotation               | ✕ |
# | IRI                      | - |
# | Class Axiom              | ✓ |
# | SubClassOf               | ✓ |
# | EquivalentClasses        | ✓ |
# | DisjointClasses          | ✓ |
# | DisjointUnion            | ✓ |
# | DataType                 | ! |
# | DataComplementOf         | ✕ |
# | DataUnionOf              | ✕ |
# | DataIntersectionOf       | ✕ |
# | DataOneOf                | ✕ |
# | DatatypeRestriction      | ✕ |
# | Class                    | ✓ |
# | Class expression         | ✓ |
# | ObjectProperty           | ✓ |
# | ObjectIntersectionOf     | ✓ |
# | ObjectUnionOf            | ✓ |
# | ObjectComplementOf       | ✓ |
# | ObjectOneOf          | ✓ |
# | ObjectSomeValuesFrom | ✓ |
# | ObjectAllValuesFrom  | ✓ |
# | ObjectHasValue       | ✓ |
# | ObjectMinCardinality | ✓ |
# | ObjectMaxCardinality | ✓ |
# | ObjectExactCardinality | ✓ |
# | ObjectPropertyAxiom       | ✕ |
# | SubObjectPropertyOf        | ✕ |
# | EquivalentObjectProperties        | ✕ |
# | DisjointObjectProperties        | ✕ |
# | InverseObjectProperties        | - |
# | ObjectPropertyDomain        | ✕ |
# | ObjectPropertyRange         | ✕ |
# | FunctionalObjectProperty         | ✕ |
# | InverseFunctionalObjectProperty         | ✕ |
# | ReflexiveObjectProperty         | ✕ |
# | IrreflexiveObjectProperty         | ✕ |
# | SymmetricObjectProperty         | ✕ |
# | AsymmetricObjectProperty         | ✕ |
# | TransitiveObjectProperty         | ✕ |
# | DataProperty             | ✓ |
# | InverseDataProperty      | ✓ |
# | DataSomeValuesFrom       | ✓ |
# | DataAllValuesFrom       | ✓ |
# | DataHasValue             | ✓ |
# | DataMinCardinality       | ✓ |
# | DataMaxCardinality       | ✓ |
# | DataExactCardinality      | ✓ |
# | SubDataPropertyOf       | ✕ |
# | EquivalentDataProperties       | ✕ |
# | DataPropertyDomain        | ✕ |
# | DataPropertyRange       | ✕ |
# | FunctionalDataProperty       | ✕ |
# | HasKey                    | ✕ |
# | AnnotationProperty       | ✕ |
# | NamedIndividual          | ✓ |
# | AnnonymousIndividual     | - |
# | SameIndividual      | ✓ |
# | DifferentIndividuals      | ✓ |
#
# * ('-' denotes that such may not have independent command or visual notation but can be displayed by labeling)
#
# [1] F. Haag, S. Lohmann, S. Negru, and T. Ertl, “OntoViBe 2: Advancing the ontology visualization benchmark,” Lect. Notes Comput. Sci. (including Subser. Lect. Notes Artif. Intell. Lect. Notes Bioinformatics), vol. 8982, pp. 83–98, 2015, doi: 10.1007/978-3-319-17966-7_9.

# %%
from owlready2 import *

# list of constructs
onto = owlready2.get_ontology("https://example.org/nowl/benchmark/onto.owl")

with onto:

    class SimpleClass1(Thing): pass
    
    class SimpleClass2(Thing): pass
    
    class SimpleClass3(Thing): pass
    
    class simpleProperty1(ObjectProperty): 
        domain = [SimpleClass1]
        range = [SimpleClass2]
    
    class simpleProperty2(ObjectProperty): 
        domain = [SimpleClass2]
        range = [SimpleClass3]
    
    class simpleProperty3(ObjectProperty): 
        domain = [SimpleClass3]
        range = [SimpleClass1]
    
    class simpleDataProperty1(DataProperty):
        range = [int]
    
    class simpleDataProperty2(DataProperty):
        range = [str]
    
    class simpleDataProperty3(DataProperty):
        range = [float]
    
    individual1 = SimpleClass1("individual1")
    
    individual2 = SimpleClass2("individual2")
    
    individual3 = SimpleClass3("individual3")

    class EquivalentClass(Thing): 
        equivalent_to = [SimpleClass1]
    class SubClass(SimpleClass1): 
        pass
    # class DisjointClass(Thing):
    #     disjoint_from = [SimpleClass1]
    class UnionClass(Thing): 
        equivalent_to = [SimpleClass1 | SimpleClass2]

    class IntersectionClass(Thing):
        equivalent_to = [SimpleClass1 & SimpleClass2]
    
    class ComplementClass(Thing):
        equivalent_to = [Not(SimpleClass1)]
    
    class OneOfClass(Thing): pass
    OneOfClass.is_a.append(OneOf([individual1, individual2, individual3]))
    
    class SomeValuesFromClass(Thing):
        equivalent_to = [simpleProperty1.some(SimpleClass2)]
    
    class AllValuesFromClass(Thing):
        equivalent_to = [simpleProperty2.only(SimpleClass3)]
    
    class ValueClass(Thing):
        equivalent_to = [simpleProperty3.value(individual1)]
    
    class SelfClass(Thing):
        equivalent_to = [simpleProperty1.has_self(True)]
    
    class MinCardinalityClass(Thing):
        equivalent_to = [simpleProperty1.min(1, SimpleClass2)]
    
    class MaxCardinalityClass(Thing):
        equivalent_to = [simpleProperty2.max(3, SimpleClass3)]
    
    class ExactCardinalityClass(Thing):
        equivalent_to = [simpleProperty3.exactly(2, SimpleClass1)]
    
    class DataSomeValueClass(Thing):
        equivalent_to = [simpleDataProperty1.some(int)]
    
    class DataAllValueClass(Thing):
        equivalent_to = [simpleDataProperty2.only(str)]
    
    class DataValueClass(Thing):
        equivalent_to = [simpleDataProperty3.value(1.0)]
    
    class DataMinCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty1.min(1, int)]
    
    class DataMaxCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty2.max(3, str)]
    
    class DataExactCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty3.exactly(2, float)]

    # individual1.equivalent_to = [individual2]
    
    AllDisjoint([SimpleClass1, SimpleClass2, SimpleClass3])

    AllDifferent([individual1, individual3])
    
    class_list = [
        EquivalentClass,
        SubClass,
        UnionClass,
        IntersectionClass,
        ComplementClass,
        OneOfClass,
        SomeValuesFromClass,
        AllValuesFromClass,
        ValueClass,
        SelfClass,
        MinCardinalityClass,
        MaxCardinalityClass,
        ExactCardinalityClass,
        DataSomeValueClass,
        DataAllValueClass,
        DataValueClass,
        DataMinCardinalityClass,
        DataMaxCardinalityClass,
        DataExactCardinalityClass
    ] #if axiom 1 is not in [dataa...], 
    

#     axioms = {
#         "SimpleClass": SimpleClass1,
#         "SomeValues": SomeValuesFromClass.equivalent_to[0],
#         "AllValues": AllValuesFromClass.equivalent_to[0]
#     }
#     concat = []
#     for name1, axiom1 in axioms.items():
#         for name2, axiom2 in axioms.items():
#             classLabel = f"{name1}_{name2}"
#             print(classLabel, axiom1, axiom2)
#             newClass = types.new_class(classLabel, (Thing,))
#             newClass.equivalent_to.append(axiom1 & axiom2)

#     print(SomeValuesFromClass.equivalent_to)
#     newClass = types.new_class("test", (Thing,))
#     newClass.equivalent_to.append(simpleProperty1.some(simpleProperty1.some(SimpleClass1)))

# onto.save(file = "benchmark.rdf", format = "rdfxml")
# print(newClass.equivalent_to)
    
# onto.destroy(update_relation = True, update_is_a = True)
# print(newClass.equivalent_to)
# print(onto)
# Out:
# SimpleClass_SimpleClass onto.SimpleClass1 onto.SimpleClass1
# SimpleClass_SomeValues onto.SimpleClass1 onto.simpleProperty1.some(onto.SimpleClass2)
# SimpleClass_AllValues onto.SimpleClass1 onto.simpleProperty2.only(onto.SimpleClass3)
# SomeValues_SimpleClass onto.simpleProperty1.some(onto.SimpleClass2) onto.SimpleClass1
# SomeValues_SomeValues onto.simpleProperty1.some(onto.SimpleClass2) onto.simpleProperty1.some(onto.SimpleClass2)
# SomeValues_AllValues onto.simpleProperty1.some(onto.SimpleClass2) onto.simpleProperty2.only(onto.SimpleClass3)
# AllValues_SimpleClass onto.simpleProperty2.only(onto.SimpleClass3) onto.SimpleClass1
# AllValues_SomeValues onto.simpleProperty2.only(onto.SimpleClass3) onto.simpleProperty1.some(onto.SimpleClass2)
# AllValues_AllValues onto.simpleProperty2.only(onto.SimpleClass3) onto.simpleProperty2.only(onto.SimpleClass3)
# [onto.simpleProperty1.some(onto.SimpleClass2)]
# [onto.simpleProperty1.some(onto.simpleProperty1.some(onto.SimpleClass1))]
# [onto.simpleProperty1.some(onto.simpleProperty1.some(onto.SimpleClass1))]
# get_ontology("https://example.org/nowl/benchmark/onto.owl#")

# %%
from owlready2 import *
import itertools

# Define constants for restriction types if they're not available in owlready2
try:
    from owlready2 import SOME, ONLY, VALUE, HAS_SELF, MIN, MAX, EXACTLY
except ImportError:
    # Define fallback constants
    SOME = "some"
    ONLY = "only"
    VALUE = "value"
    HAS_SELF = "has_self"
    MIN = "min"
    MAX = "max"
    EXACTLY = "exactly"

# Setup ontology
onto = get_ontology("http://example.org/nested-expressions/")

with onto:
    # Base classes
    class SimpleClass1(Thing): pass
    class SimpleClass2(Thing): pass
    class SimpleClass3(Thing): pass
    
    # Properties
    class simpleProperty1(ObjectProperty): pass
    class simpleProperty2(ObjectProperty): pass
    class simpleProperty3(ObjectProperty): pass
    
    class simpleDataProperty1(DataProperty): pass
    class simpleDataProperty2(DataProperty): pass
    class simpleDataProperty3(DataProperty): pass
    
    # Individuals
    individual1 = SimpleClass1("individual1")
    individual2 = SimpleClass1("individual2")
    individual3 = SimpleClass2("individual3")
    
    # Define the original class expressions
    class EquivalentClass(Thing): 
        equivalent_to = [SimpleClass1]
    
    class SubClass(SimpleClass1): pass
    
    class UnionClass(Thing): 
        equivalent_to = [SimpleClass1 | SimpleClass2]
    
    class IntersectionClass(Thing):
        equivalent_to = [SimpleClass1 & SimpleClass2]
    
    class ComplementClass(Thing):
        equivalent_to = [Not(SimpleClass1)]
    
    class OneOfClass(Thing): pass
    OneOfClass.is_a.append(OneOf([individual1, individual2, individual3]))
    
    class SomeValuesFromClass(Thing):
        equivalent_to = [simpleProperty1.some(SimpleClass2)]
    
    class AllValuesFromClass(Thing):
        equivalent_to = [simpleProperty2.only(SimpleClass3)]
    
    class ValueClass(Thing):
        equivalent_to = [simpleProperty3.value(individual1)]
    
    class SelfClass(Thing):
        equivalent_to = [simpleProperty1.has_self(True)]
    
    class MinCardinalityClass(Thing):
        equivalent_to = [simpleProperty1.min(1, SimpleClass2)]
    
    class MaxCardinalityClass(Thing):
        equivalent_to = [simpleProperty2.max(3, SimpleClass3)]
    
    class ExactCardinalityClass(Thing):
        equivalent_to = [simpleProperty3.exactly(2, SimpleClass1)]
    
    class DataSomeValueClass(Thing):
        equivalent_to = [simpleDataProperty1.some(int)]
    
    class DataAllValueClass(Thing):
        equivalent_to = [simpleDataProperty2.only(str)]
    
    class DataValueClass(Thing):
        equivalent_to = [simpleDataProperty3.value(1.0)]
    
    class DataMinCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty1.min(1, int)]
    
    class DataMaxCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty2.max(3, str)]
    
    class DataExactCardinalityClass(Thing):
        equivalent_to = [simpleDataProperty3.exactly(2, float)]
    
    # Set up disjoint classes
    AllDisjoint([SimpleClass1, SimpleClass2, SimpleClass3])
    
    # Set up different individuals
    AllDifferent([individual1, individual3])

    # Function to get class expression from a class
    def get_class_expression(cls):
        try:
            if hasattr(cls, 'equivalent_to') and cls.equivalent_to:
                return cls.equivalent_to[0]
            elif hasattr(cls, 'is_a') and len(cls.is_a) > 1:
                # For classes like OneOfClass that use is_a.append
                for expr in cls.is_a:
                    if not isinstance(expr, ThingClass):
                        return expr
            
            # Special handling for certain class types
            if cls.__name__ == "SelfClass" and hasattr(simpleProperty1, 'has_self'):
                return simpleProperty1.has_self(True)
            elif cls.__name__ == "OneOfClass":
                return OneOf([individual1, individual2, individual3])
            
            return cls  # Default case, return the class itself
        except Exception as e:
            print(f"Error getting expression for {cls.__name__}: {e}")
            return cls

    # Function to create a new combined class expression based on the type of cls1
    def combine_expressions(cls1, expr1, expr2, name1, name2):
        class_label = f"{name1}_{name2}"
        print(f"Creating {class_label}")
        
        if isinstance(expr1, Or):
            # Union case
            new_expr = expr1 | expr2
            print(f"  Union: {expr2} | {expr2}")
            new_class = types.new_class(class_label, (Thing,))
            new_class.equivalent_to.append(new_expr)
            
        elif isinstance(expr1, And):
            # Intersection case
            new_expr = expr1 & expr2
            print(f"  Intersection: {expr2} & {expr2}")
            new_class = types.new_class(class_label, (Thing,))
            new_class.equivalent_to.append(new_expr)
            
        elif isinstance(expr1, Not):
            # Complement case
            new_expr = Not(expr2)
            print(f"  Complement: Not({expr2})")
            new_class = types.new_class(class_label, (Thing,))
            new_class.equivalent_to.append(new_expr)
            
        elif isinstance(expr1, OneOf):
            # OneOf case
            if hasattr(expr2, 'instances'):
                individuals = list(expr2.instances())
                if individuals:
                    new_expr = OneOf(individuals)
                    print(f"  OneOf: OneOf({individuals})")
                    new_class = types.new_class(class_label, (Thing,))
                    new_class.is_a.append(new_expr)
                else:
                    print(f"  Skipping {class_label}: No instances for {expr2}")
                    return None
            else:
                print(f"  Skipping {class_label}: Cannot create OneOf with {expr2}")
                return None
            
        elif hasattr(expr1, 'property'):
            # Restriction cases
            prop = expr1.property
            
            # Determine restriction type based on the type string or constant
            restriction_type = str(expr1.type) if hasattr(expr1, 'type') else ""
            
            if restriction_type.endswith('#someValuesFrom') or (hasattr(expr1, 'type') and expr1.type == SOME):
                # some case
                new_expr = prop.some(expr2)
                print(f"  Some: {prop}.some({expr2})")
                new_class = types.new_class(class_label, (Thing,))
                new_class.equivalent_to.append(new_expr)
                
            elif restriction_type.endswith('#allValuesFrom') or (hasattr(expr1, 'type') and expr1.type == ONLY):
                # only case
                new_expr = prop.only(expr2)
                print(f"  Only: {prop}.only({expr2})")
                new_class = types.new_class(class_label, (Thing,))
                new_class.equivalent_to.append(new_expr)
                
            elif restriction_type.endswith('#hasValue') or (hasattr(expr1, 'type') and expr1.type == VALUE):
                # value case
                # For value restrictions, we need an individual
                try:
                    if hasattr(expr1, 'value'):
                        value_to_use = expr1.value if isinstance(expr2, ThingClass) else expr2
                        new_expr = prop.value(value_to_use)
                        print(f"  Value: {prop}.value({value_to_use})")
                        new_class = types.new_class(class_label, (Thing,))
                        new_class.equivalent_to.append(new_expr)
                    else:
                        print(f"  Skipping {class_label}: Cannot determine value for {expr1}")
                        return None
                except Exception as e:
                    print(f"  Skipping {class_label}: Error creating value restriction: {e}")
                    return None
                
            elif restriction_type.endswith('#hasSelf') or (hasattr(expr1, 'type') and str(expr1.type).endswith('#hasSelf')):
                # has_self case
                new_expr = prop.has_self(True)
                print(f"  Has_Self: {prop}.has_self(True)")
                new_class = types.new_class(class_label, (Thing,))
                new_class.equivalent_to.append(new_expr)
                
            elif restriction_type.endswith('#minCardinality') or restriction_type.endswith('#minQualifiedCardinality') or (hasattr(expr1, 'type') and expr1.type == MIN):
                # min case
                try:
                    card = expr1.cardinality if hasattr(expr1, 'cardinality') else 1
                    new_expr = prop.min(card, expr2)
                    print(f"  Min: {prop}.min({card}, {expr2})")
                    new_class = types.new_class(class_label, (Thing,))
                    new_class.equivalent_to.append(new_expr)
                except Exception as e:
                    print(f"  Skipping {class_label}: Error creating min restriction: {e}")
                    return None
                
            elif restriction_type.endswith('#maxCardinality') or restriction_type.endswith('#maxQualifiedCardinality') or (hasattr(expr1, 'type') and expr1.type == MAX):
                # max case
                try:
                    card = expr1.cardinality if hasattr(expr1, 'cardinality') else 3
                    new_expr = prop.max(card, expr2)
                    print(f"  Max: {prop}.max({card}, {expr2})")
                    new_class = types.new_class(class_label, (Thing,))
                    new_class.equivalent_to.append(new_expr)
                except Exception as e:
                    print(f"  Skipping {class_label}: Error creating max restriction: {e}")
                    return None
                
            elif restriction_type.endswith('#cardinality') or restriction_type.endswith('#qualifiedCardinality') or (hasattr(expr1, 'type') and expr1.type == EXACTLY):
                # exactly case
                try:
                    card = expr1.cardinality if hasattr(expr1, 'cardinality') else 2
                    new_expr = prop.exactly(card, expr2)
                    print(f"  Exactly: {prop}.exactly({card}, {expr2})")
                    new_class = types.new_class(class_label, (Thing,))
                    new_class.equivalent_to.append(new_expr)
                except Exception as e:
                    print(f"  Skipping {class_label}: Error creating exactly restriction: {e}")
                    return None
                
            else:
                print(f"  Skipping {class_label}: Unsupported restriction type {expr1.type}")
                return None
            
        else:
            # Simple subclass case
            print(f"  Subclass: {expr2}")
            new_class = types.new_class(class_label, (expr2,))
            
        return new_class

    # Main code to generate nested class expressions
    def generate_nested_expressions(class_list, max_combinations=2):
        """
        Generate nested class expressions by combining the provided classes.
        max_combinations: Maximum depth of nesting to generate.
        """
        generated_classes = {}
        
        # Define data property classes to skip as expr1
        data_property_classes = {
            DataSomeValueClass,
            DataAllValueClass,
            DataValueClass,
            DataMinCardinalityClass,
            DataMaxCardinalityClass,
            DataExactCardinalityClass
        }
        
        # For each combination of 2 classes
        for depth in range(1, max_combinations + 1):
            print(f"\n=== Generating combinations at depth {depth} ===")
            
            # Use different combinations based on depth
            if depth == 1:
                # At depth 1, just loop through the classes to get their expressions
                for cls in class_list:
                    cls_name = cls.__name__
                    try:
                        expr = get_class_expression(cls)
                        print(f"{cls_name}: {expr}")
                        generated_classes[cls_name] = expr
                    except Exception as e:
                        print(f"Error processing {cls_name}: {e}")
            else:
                # At depth > 1, combine classes
                combinations_done = set()
                
                for i, cls1 in enumerate(class_list):
                    # Skip if cls1 is a data property class
                    if cls1 in data_property_classes:
                        print(f"Skipping combinations with {cls1.__name__} as first expression (data property class)")
                        continue
                        
                    for j, cls2 in enumerate(class_list):
                        # if i == j:
                        #     continue  # Skip same class combinations
                        
                        # Create a unique key for this combination
                        combo_key = f"{i}_{j}"
                        if combo_key in combinations_done:
                            continue  # Skip already processed combinations
                        
                        combinations_done.add(combo_key)
                        
                        try:
                            cls1_name = cls1.__name__
                            cls2_name = cls2.__name__
                            
                            expr1 = get_class_expression(cls1)
                            expr2 = get_class_expression(cls2)
                            
                            # Skip combinations where we can't get proper expressions
                            if expr1 is cls1 and not issubclass(cls1, Thing):
                                continue
                            if expr2 is cls2 and not issubclass(cls2, Thing):
                                continue
                            
                            # Combine the expressions based on expr1's type
                            combine_expressions(cls1, expr1, expr2, cls1_name, cls2_name)
                        except Exception as e:
                            print(f"Error combining {cls1.__name__} and {cls2.__name__}: {e}")
        
        return generated_classes

    # Define the classes to use in combinations
    class_list = [
        EquivalentClass,
        SubClass,
        UnionClass,
        IntersectionClass,
        ComplementClass,
        OneOfClass,
        SomeValuesFromClass,
        AllValuesFromClass,
        ValueClass,
        SelfClass,
        MinCardinalityClass,
        MaxCardinalityClass,
        ExactCardinalityClass,
        DataSomeValueClass,
        DataAllValueClass,
        DataValueClass,
        DataMinCardinalityClass,
        DataMaxCardinalityClass,
        DataExactCardinalityClass
    ] #if axiom 1 is not in [dataa...], 

    try:
        # Generate nested expressions with a maximum depth of 2
        generated = generate_nested_expressions(class_list, max_combinations=3)
        
        # Count the total number of generated classes
        total_classes = len(list(onto.classes()))
        original_classes = len(class_list) + 3  # +3 for SimpleClass1, SimpleClass2, SimpleClass3
        new_classes = total_classes - original_classes
        
        print(f"\nTotal new class expressions generated: {new_classes}")
        
        # Save the ontology
        try:
            onto.save(file="nested_expressions.rdf", format="rdfxml")
            print("Ontology saved to nested_expressions.owl")
        except Exception as e:
            print(f"Error saving ontology: {e}")
            
        # Print out a sample of complex nested expressions
        print("\nSample of generated class expressions:")
        sample_count = min(5, new_classes)
        sample_classes = list(onto.classes())[-sample_count:] if sample_count > 0 else []
        
        for cls in sample_classes:
            print(f"{cls.name}:")
            if hasattr(cls, 'equivalent_to') and cls.equivalent_to:
                print(f"  Equivalent to: {cls.equivalent_to[0]}")
            elif len(cls.is_a) > 1:
                print(f"  Subclass of: {', '.join(str(c) for c in cls.is_a)}")
            else:
                print("  No expressions found")
                
    except Exception as e:
        print(f"Error during nested expression generation: {e}")
# Out:
# === Generating combinations at depth 1 ===
# EquivalentClass: nested-expressions.SimpleClass1
# SubClass: nested-expressions.SubClass
# UnionClass: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# IntersectionClass: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# ComplementClass: Not(nested-expressions.SimpleClass1)
# OneOfClass: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# SomeValuesFromClass: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# AllValuesFromClass: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# ValueClass: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# SelfClass: nested-expressions.simpleProperty1.has_self()
# MinCardinalityClass: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# MaxCardinalityClass: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# ExactCardinalityClass: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# DataSomeValueClass: nested-expressions.simpleDataProperty1.some(<class 'int'>)
# DataAllValueClass: nested-expressions.simpleDataProperty2.only(<class 'str'>)
# DataValueClass: nested-expressions.simpleDataProperty3.value(1.0)
# DataMinCardinalityClass: nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# DataMaxCardinalityClass: nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# DataExactCardinalityClass: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
#
# === Generating combinations at depth 2 ===
# Creating EquivalentClass_EquivalentClass
#   Subclass: nested-expressions.SimpleClass1
# Creating EquivalentClass_SubClass
#   Subclass: nested-expressions.SubClass
# Creating EquivalentClass_UnionClass
#   Subclass: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Error combining EquivalentClass and UnionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating EquivalentClass_IntersectionClass
#   Subclass: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Error combining EquivalentClass and IntersectionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating EquivalentClass_ComplementClass
#   Subclass: Not(nested-expressions.SimpleClass1)
# Error combining EquivalentClass and ComplementClass: 'tuple' object has no attribute '_set_obj_triple_spo'
# Creating EquivalentClass_OneOfClass
#   Subclass: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Error combining EquivalentClass and OneOfClass: 'tuple' object has no attribute 'world'
# Creating EquivalentClass_SomeValuesFromClass
#   Subclass: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating EquivalentClass_AllValuesFromClass
#   Subclass: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating EquivalentClass_ValueClass
#   Subclass: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating EquivalentClass_SelfClass
#   Subclass: nested-expressions.simpleProperty1.has_self()
# Creating EquivalentClass_MinCardinalityClass
#   Subclass: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating EquivalentClass_MaxCardinalityClass
#   Subclass: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating EquivalentClass_ExactCardinalityClass
#   Subclass: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating EquivalentClass_DataSomeValueClass
#   Subclass: nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating EquivalentClass_DataAllValueClass
#   Subclass: nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating EquivalentClass_DataValueClass
#   Subclass: nested-expressions.simpleDataProperty3.value(1.0)
# Creating EquivalentClass_DataMinCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating EquivalentClass_DataMaxCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating EquivalentClass_DataExactCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating SubClass_EquivalentClass
#   Subclass: nested-expressions.SimpleClass1
# Creating SubClass_SubClass
#   Subclass: nested-expressions.SubClass
# Creating SubClass_UnionClass
#   Subclass: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Error combining SubClass and UnionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating SubClass_IntersectionClass
#   Subclass: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Error combining SubClass and IntersectionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating SubClass_ComplementClass
#   Subclass: Not(nested-expressions.SimpleClass1)
# Error combining SubClass and ComplementClass: 'tuple' object has no attribute '_set_obj_triple_spo'
# Creating SubClass_OneOfClass
#   Subclass: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Error combining SubClass and OneOfClass: 'tuple' object has no attribute 'world'
# Creating SubClass_SomeValuesFromClass
#   Subclass: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating SubClass_AllValuesFromClass
#   Subclass: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating SubClass_ValueClass
#   Subclass: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating SubClass_SelfClass
#   Subclass: nested-expressions.simpleProperty1.has_self()
# Creating SubClass_MinCardinalityClass
#   Subclass: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating SubClass_MaxCardinalityClass
#   Subclass: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating SubClass_ExactCardinalityClass
#   Subclass: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating SubClass_DataSomeValueClass
#   Subclass: nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating SubClass_DataAllValueClass
#   Subclass: nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating SubClass_DataValueClass
#   Subclass: nested-expressions.simpleDataProperty3.value(1.0)
# Creating SubClass_DataMinCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating SubClass_DataMaxCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating SubClass_DataExactCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating UnionClass_EquivalentClass
#   Union: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass1
# Creating UnionClass_SubClass
#   Union: nested-expressions.SubClass | nested-expressions.SubClass
# Creating UnionClass_UnionClass
#   Union: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2 | nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Creating UnionClass_IntersectionClass
#   Union: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2 | nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Creating UnionClass_ComplementClass
#   Union: Not(nested-expressions.SimpleClass1) | Not(nested-expressions.SimpleClass1)
# Creating UnionClass_OneOfClass
#   Union: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]) | OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Creating UnionClass_SomeValuesFromClass
#   Union: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2) | nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating UnionClass_AllValuesFromClass
#   Union: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3) | nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating UnionClass_ValueClass
#   Union: nested-expressions.simpleProperty3.value(nested-expressions.individual1) | nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating UnionClass_SelfClass
#   Union: nested-expressions.simpleProperty1.has_self() | nested-expressions.simpleProperty1.has_self()
# Creating UnionClass_MinCardinalityClass
#   Union: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2) | nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating UnionClass_MaxCardinalityClass
#   Union: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3) | nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating UnionClass_ExactCardinalityClass
#   Union: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1) | nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating UnionClass_DataSomeValueClass
#   Union: nested-expressions.simpleDataProperty1.some(<class 'int'>) | nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating UnionClass_DataAllValueClass
#   Union: nested-expressions.simpleDataProperty2.only(<class 'str'>) | nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating UnionClass_DataValueClass
#   Union: nested-expressions.simpleDataProperty3.value(1.0) | nested-expressions.simpleDataProperty3.value(1.0)
# Creating UnionClass_DataMinCardinalityClass
#   Union: nested-expressions.simpleDataProperty1.min(1, <class 'int'>) | nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating UnionClass_DataMaxCardinalityClass
#   Union: nested-expressions.simpleDataProperty2.max(3, <class 'str'>) | nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating UnionClass_DataExactCardinalityClass
#   Union: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>) | nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating IntersectionClass_EquivalentClass
#   Intersection: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass1
# Creating IntersectionClass_SubClass
#   Intersection: nested-expressions.SubClass & nested-expressions.SubClass
# Creating IntersectionClass_UnionClass
#   Intersection: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2 & nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Creating IntersectionClass_IntersectionClass
#   Intersection: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2 & nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Creating IntersectionClass_ComplementClass
#   Intersection: Not(nested-expressions.SimpleClass1) & Not(nested-expressions.SimpleClass1)
# Creating IntersectionClass_OneOfClass
#   Intersection: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]) & OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Creating IntersectionClass_SomeValuesFromClass
#   Intersection: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2) & nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating IntersectionClass_AllValuesFromClass
#   Intersection: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3) & nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating IntersectionClass_ValueClass
#   Intersection: nested-expressions.simpleProperty3.value(nested-expressions.individual1) & nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating IntersectionClass_SelfClass
#   Intersection: nested-expressions.simpleProperty1.has_self() & nested-expressions.simpleProperty1.has_self()
# Creating IntersectionClass_MinCardinalityClass
#   Intersection: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2) & nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating IntersectionClass_MaxCardinalityClass
#   Intersection: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3) & nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating IntersectionClass_ExactCardinalityClass
#   Intersection: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1) & nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating IntersectionClass_DataSomeValueClass
#   Intersection: nested-expressions.simpleDataProperty1.some(<class 'int'>) & nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating IntersectionClass_DataAllValueClass
#   Intersection: nested-expressions.simpleDataProperty2.only(<class 'str'>) & nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating IntersectionClass_DataValueClass
#   Intersection: nested-expressions.simpleDataProperty3.value(1.0) & nested-expressions.simpleDataProperty3.value(1.0)
# Creating IntersectionClass_DataMinCardinalityClass
#   Intersection: nested-expressions.simpleDataProperty1.min(1, <class 'int'>) & nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating IntersectionClass_DataMaxCardinalityClass
#   Intersection: nested-expressions.simpleDataProperty2.max(3, <class 'str'>) & nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating IntersectionClass_DataExactCardinalityClass
#   Intersection: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>) & nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating ComplementClass_EquivalentClass
#   Complement: Not(nested-expressions.SimpleClass1)
# Creating ComplementClass_SubClass
#   Complement: Not(nested-expressions.SubClass)
# Creating ComplementClass_UnionClass
#   Complement: Not(nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating ComplementClass_IntersectionClass
#   Complement: Not(nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating ComplementClass_ComplementClass
#   Complement: Not(Not(nested-expressions.SimpleClass1))
# Creating ComplementClass_OneOfClass
#   Complement: Not(OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating ComplementClass_SomeValuesFromClass
#   Complement: Not(nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating ComplementClass_AllValuesFromClass
#   Complement: Not(nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating ComplementClass_ValueClass
#   Complement: Not(nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating ComplementClass_SelfClass
#   Complement: Not(nested-expressions.simpleProperty1.has_self())
# Creating ComplementClass_MinCardinalityClass
#   Complement: Not(nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating ComplementClass_MaxCardinalityClass
#   Complement: Not(nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating ComplementClass_ExactCardinalityClass
#   Complement: Not(nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating ComplementClass_DataSomeValueClass
#   Complement: Not(nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating ComplementClass_DataAllValueClass
#   Complement: Not(nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating ComplementClass_DataValueClass
#   Complement: Not(nested-expressions.simpleDataProperty3.value(1.0))
# Creating ComplementClass_DataMinCardinalityClass
#   Complement: Not(nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating ComplementClass_DataMaxCardinalityClass
#   Complement: Not(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating ComplementClass_DataExactCardinalityClass
#   Complement: Not(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating OneOfClass_EquivalentClass
#   OneOf: OneOf([nested-expressions.individual1, nested-expressions.individual2])
# Creating OneOfClass_SubClass
#   Skipping OneOfClass_SubClass: No instances for nested-expressions.SubClass
# Creating OneOfClass_UnionClass
#   Skipping OneOfClass_UnionClass: Cannot create OneOf with nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Creating OneOfClass_IntersectionClass
#   Skipping OneOfClass_IntersectionClass: Cannot create OneOf with nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Creating OneOfClass_ComplementClass
#   Skipping OneOfClass_ComplementClass: Cannot create OneOf with Not(nested-expressions.SimpleClass1)
# Creating OneOfClass_OneOfClass
# Error combining OneOfClass and OneOfClass: 'CallbackList' object is not callable
# Creating OneOfClass_SomeValuesFromClass
#   Skipping OneOfClass_SomeValuesFromClass: Cannot create OneOf with nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating OneOfClass_AllValuesFromClass
#   Skipping OneOfClass_AllValuesFromClass: Cannot create OneOf with nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating OneOfClass_ValueClass
#   Skipping OneOfClass_ValueClass: Cannot create OneOf with nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating OneOfClass_SelfClass
#   Skipping OneOfClass_SelfClass: Cannot create OneOf with nested-expressions.simpleProperty1.has_self()
# Creating OneOfClass_MinCardinalityClass
#   Skipping OneOfClass_MinCardinalityClass: Cannot create OneOf with nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating OneOfClass_MaxCardinalityClass
#   Skipping OneOfClass_MaxCardinalityClass: Cannot create OneOf with nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating OneOfClass_ExactCardinalityClass
#   Skipping OneOfClass_ExactCardinalityClass: Cannot create OneOf with nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating OneOfClass_DataSomeValueClass
#   Skipping OneOfClass_DataSomeValueClass: Cannot create OneOf with nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating OneOfClass_DataAllValueClass
#   Skipping OneOfClass_DataAllValueClass: Cannot create OneOf with nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating OneOfClass_DataValueClass
#   Skipping OneOfClass_DataValueClass: Cannot create OneOf with nested-expressions.simpleDataProperty3.value(1.0)
# Creating OneOfClass_DataMinCardinalityClass
#   Skipping OneOfClass_DataMinCardinalityClass: Cannot create OneOf with nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating OneOfClass_DataMaxCardinalityClass
#   Skipping OneOfClass_DataMaxCardinalityClass: Cannot create OneOf with nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating OneOfClass_DataExactCardinalityClass
#   Skipping OneOfClass_DataExactCardinalityClass: Cannot create OneOf with nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating SomeValuesFromClass_EquivalentClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass1)
# Creating SomeValuesFromClass_SubClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.SubClass)
# Creating SomeValuesFromClass_UnionClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating SomeValuesFromClass_IntersectionClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating SomeValuesFromClass_ComplementClass
#   Some: nested-expressions.simpleProperty1.some(Not(nested-expressions.SimpleClass1))
# Creating SomeValuesFromClass_OneOfClass
#   Some: nested-expressions.simpleProperty1.some(OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating SomeValuesFromClass_SomeValuesFromClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating SomeValuesFromClass_AllValuesFromClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating SomeValuesFromClass_ValueClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating SomeValuesFromClass_SelfClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty1.has_self())
# Creating SomeValuesFromClass_MinCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating SomeValuesFromClass_MaxCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating SomeValuesFromClass_ExactCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating SomeValuesFromClass_DataSomeValueClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating SomeValuesFromClass_DataAllValueClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating SomeValuesFromClass_DataValueClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty3.value(1.0))
# Creating SomeValuesFromClass_DataMinCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating SomeValuesFromClass_DataMaxCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating SomeValuesFromClass_DataExactCardinalityClass
#   Some: nested-expressions.simpleProperty1.some(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating AllValuesFromClass_EquivalentClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass1)
# Creating AllValuesFromClass_SubClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.SubClass)
# Creating AllValuesFromClass_UnionClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating AllValuesFromClass_IntersectionClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating AllValuesFromClass_ComplementClass
#   Only: nested-expressions.simpleProperty2.only(Not(nested-expressions.SimpleClass1))
# Creating AllValuesFromClass_OneOfClass
#   Only: nested-expressions.simpleProperty2.only(OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating AllValuesFromClass_SomeValuesFromClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating AllValuesFromClass_AllValuesFromClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating AllValuesFromClass_ValueClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating AllValuesFromClass_SelfClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty1.has_self())
# Creating AllValuesFromClass_MinCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating AllValuesFromClass_MaxCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating AllValuesFromClass_ExactCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating AllValuesFromClass_DataSomeValueClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating AllValuesFromClass_DataAllValueClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating AllValuesFromClass_DataValueClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty3.value(1.0))
# Creating AllValuesFromClass_DataMinCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating AllValuesFromClass_DataMaxCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating AllValuesFromClass_DataExactCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating ValueClass_EquivalentClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating ValueClass_SubClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating ValueClass_UnionClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating ValueClass_IntersectionClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating ValueClass_ComplementClass
#   Value: nested-expressions.simpleProperty3.value(Not(nested-expressions.SimpleClass1))
# Creating ValueClass_OneOfClass
#   Value: nested-expressions.simpleProperty3.value(OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating ValueClass_SomeValuesFromClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating ValueClass_AllValuesFromClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating ValueClass_ValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating ValueClass_SelfClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.has_self())
# Creating ValueClass_MinCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating ValueClass_MaxCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating ValueClass_ExactCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating ValueClass_DataSomeValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating ValueClass_DataAllValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating ValueClass_DataValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty3.value(1.0))
# Creating ValueClass_DataMinCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating ValueClass_DataMaxCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating ValueClass_DataExactCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating SelfClass_EquivalentClass
#   Skipping SelfClass_EquivalentClass: Unsupported restriction type 117
# Creating SelfClass_SubClass
#   Skipping SelfClass_SubClass: Unsupported restriction type 117
# Creating SelfClass_UnionClass
#   Skipping SelfClass_UnionClass: Unsupported restriction type 117
# Creating SelfClass_IntersectionClass
#   Skipping SelfClass_IntersectionClass: Unsupported restriction type 117
# Creating SelfClass_ComplementClass
#   Skipping SelfClass_ComplementClass: Unsupported restriction type 117
# Creating SelfClass_OneOfClass
#   Skipping SelfClass_OneOfClass: Unsupported restriction type 117
# Creating SelfClass_SomeValuesFromClass
#   Skipping SelfClass_SomeValuesFromClass: Unsupported restriction type 117
# Creating SelfClass_AllValuesFromClass
#   Skipping SelfClass_AllValuesFromClass: Unsupported restriction type 117
# Creating SelfClass_ValueClass
#   Skipping SelfClass_ValueClass: Unsupported restriction type 117
# Creating SelfClass_SelfClass
#   Skipping SelfClass_SelfClass: Unsupported restriction type 117
# Creating SelfClass_MinCardinalityClass
#   Skipping SelfClass_MinCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_MaxCardinalityClass
#   Skipping SelfClass_MaxCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_ExactCardinalityClass
#   Skipping SelfClass_ExactCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataSomeValueClass
#   Skipping SelfClass_DataSomeValueClass: Unsupported restriction type 117
# Creating SelfClass_DataAllValueClass
#   Skipping SelfClass_DataAllValueClass: Unsupported restriction type 117
# Creating SelfClass_DataValueClass
#   Skipping SelfClass_DataValueClass: Unsupported restriction type 117
# Creating SelfClass_DataMinCardinalityClass
#   Skipping SelfClass_DataMinCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataMaxCardinalityClass
#   Skipping SelfClass_DataMaxCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataExactCardinalityClass
#   Skipping SelfClass_DataExactCardinalityClass: Unsupported restriction type 117
# Creating MinCardinalityClass_EquivalentClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1)
# Creating MinCardinalityClass_SubClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SubClass)
# Creating MinCardinalityClass_UnionClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating MinCardinalityClass_IntersectionClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating MinCardinalityClass_ComplementClass
#   Min: nested-expressions.simpleProperty1.min(1, Not(nested-expressions.SimpleClass1))
# Creating MinCardinalityClass_OneOfClass
#   Min: nested-expressions.simpleProperty1.min(1, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating MinCardinalityClass_SomeValuesFromClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating MinCardinalityClass_AllValuesFromClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating MinCardinalityClass_ValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating MinCardinalityClass_SelfClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.has_self())
# Creating MinCardinalityClass_MinCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating MinCardinalityClass_MaxCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating MinCardinalityClass_ExactCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating MinCardinalityClass_DataSomeValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating MinCardinalityClass_DataAllValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating MinCardinalityClass_DataValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty3.value(1.0))
# Creating MinCardinalityClass_DataMinCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating MinCardinalityClass_DataMaxCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating MinCardinalityClass_DataExactCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating MaxCardinalityClass_EquivalentClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1)
# Creating MaxCardinalityClass_SubClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SubClass)
# Creating MaxCardinalityClass_UnionClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating MaxCardinalityClass_IntersectionClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating MaxCardinalityClass_ComplementClass
#   Max: nested-expressions.simpleProperty2.max(3, Not(nested-expressions.SimpleClass1))
# Creating MaxCardinalityClass_OneOfClass
#   Max: nested-expressions.simpleProperty2.max(3, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating MaxCardinalityClass_SomeValuesFromClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating MaxCardinalityClass_AllValuesFromClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating MaxCardinalityClass_ValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating MaxCardinalityClass_SelfClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.has_self())
# Creating MaxCardinalityClass_MinCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating MaxCardinalityClass_MaxCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating MaxCardinalityClass_ExactCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating MaxCardinalityClass_DataSomeValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating MaxCardinalityClass_DataAllValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating MaxCardinalityClass_DataValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty3.value(1.0))
# Creating MaxCardinalityClass_DataMinCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating MaxCardinalityClass_DataMaxCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating MaxCardinalityClass_DataExactCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating ExactCardinalityClass_EquivalentClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating ExactCardinalityClass_SubClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SubClass)
# Creating ExactCardinalityClass_UnionClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating ExactCardinalityClass_IntersectionClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating ExactCardinalityClass_ComplementClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, Not(nested-expressions.SimpleClass1))
# Creating ExactCardinalityClass_OneOfClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating ExactCardinalityClass_SomeValuesFromClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating ExactCardinalityClass_AllValuesFromClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating ExactCardinalityClass_ValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating ExactCardinalityClass_SelfClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.has_self())
# Creating ExactCardinalityClass_MinCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating ExactCardinalityClass_MaxCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating ExactCardinalityClass_ExactCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating ExactCardinalityClass_DataSomeValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating ExactCardinalityClass_DataAllValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating ExactCardinalityClass_DataValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.value(1.0))
# Creating ExactCardinalityClass_DataMinCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating ExactCardinalityClass_DataMaxCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating ExactCardinalityClass_DataExactCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Skipping combinations with DataSomeValueClass as first expression (data property class)
# Skipping combinations with DataAllValueClass as first expression (data property class)
# Skipping combinations with DataValueClass as first expression (data property class)
# Skipping combinations with DataMinCardinalityClass as first expression (data property class)
# Skipping combinations with DataMaxCardinalityClass as first expression (data property class)
# Skipping combinations with DataExactCardinalityClass as first expression (data property class)
#
# === Generating combinations at depth 3 ===
# Creating EquivalentClass_EquivalentClass
#   Subclass: nested-expressions.SimpleClass1
# Creating EquivalentClass_SubClass
#   Subclass: nested-expressions.SubClass
# Creating EquivalentClass_UnionClass
#   Subclass: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Error combining EquivalentClass and UnionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating EquivalentClass_IntersectionClass
#   Subclass: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Error combining EquivalentClass and IntersectionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating EquivalentClass_ComplementClass
#   Subclass: Not(nested-expressions.SimpleClass1)
# Error combining EquivalentClass and ComplementClass: 'tuple' object has no attribute '_set_obj_triple_spo'
# Creating EquivalentClass_OneOfClass
#   Subclass: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Error combining EquivalentClass and OneOfClass: 'tuple' object has no attribute 'world'
# Creating EquivalentClass_SomeValuesFromClass
#   Subclass: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating EquivalentClass_AllValuesFromClass
#   Subclass: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating EquivalentClass_ValueClass
#   Subclass: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating EquivalentClass_SelfClass
#   Subclass: nested-expressions.simpleProperty1.has_self()
# Creating EquivalentClass_MinCardinalityClass
#   Subclass: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating EquivalentClass_MaxCardinalityClass
#   Subclass: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating EquivalentClass_ExactCardinalityClass
#   Subclass: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating EquivalentClass_DataSomeValueClass
#   Subclass: nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating EquivalentClass_DataAllValueClass
#   Subclass: nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating EquivalentClass_DataValueClass
#   Subclass: nested-expressions.simpleDataProperty3.value(1.0)
# Creating EquivalentClass_DataMinCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating EquivalentClass_DataMaxCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating EquivalentClass_DataExactCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating SubClass_EquivalentClass
#   Subclass: nested-expressions.SimpleClass1
# Creating SubClass_SubClass
#   Subclass: nested-expressions.SubClass
# Creating SubClass_UnionClass
#   Subclass: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Error combining SubClass and UnionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating SubClass_IntersectionClass
#   Subclass: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Error combining SubClass and IntersectionClass: 'tuple' object has no attribute '_add_obj_triple_spo'
# Creating SubClass_ComplementClass
#   Subclass: Not(nested-expressions.SimpleClass1)
# Error combining SubClass and ComplementClass: 'tuple' object has no attribute '_set_obj_triple_spo'
# Creating SubClass_OneOfClass
#   Subclass: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Error combining SubClass and OneOfClass: 'tuple' object has no attribute 'world'
# Creating SubClass_SomeValuesFromClass
#   Subclass: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating SubClass_AllValuesFromClass
#   Subclass: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating SubClass_ValueClass
#   Subclass: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating SubClass_SelfClass
#   Subclass: nested-expressions.simpleProperty1.has_self()
# Creating SubClass_MinCardinalityClass
#   Subclass: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating SubClass_MaxCardinalityClass
#   Subclass: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating SubClass_ExactCardinalityClass
#   Subclass: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating SubClass_DataSomeValueClass
#   Subclass: nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating SubClass_DataAllValueClass
#   Subclass: nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating SubClass_DataValueClass
#   Subclass: nested-expressions.simpleDataProperty3.value(1.0)
# Creating SubClass_DataMinCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating SubClass_DataMaxCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating SubClass_DataExactCardinalityClass
#   Subclass: nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>)
# Creating UnionClass_EquivalentClass
#   Union: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass1
# Creating UnionClass_SubClass
#   Union: nested-expressions.SubClass | nested-expressions.SubClass
# Creating UnionClass_UnionClass
#   Union: nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2 | nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2
# Creating UnionClass_IntersectionClass
#   Union: nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2 | nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2
# Creating UnionClass_ComplementClass
#   Union: Not(nested-expressions.SimpleClass1) | Not(nested-expressions.SimpleClass1)
# Creating UnionClass_OneOfClass
#   Union: OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]) | OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3])
# Creating UnionClass_SomeValuesFromClass
#   Union: nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2) | nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2)
# Creating UnionClass_AllValuesFromClass
#   Union: nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3) | nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3)
# Creating UnionClass_ValueClass
#   Union: nested-expressions.simpleProperty3.value(nested-expressions.individual1) | nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating UnionClass_SelfClass
#   Union: nested-expressions.simpleProperty1.has_self() | nested-expressions.simpleProperty1.has_self()
# Creating UnionClass_MinCardinalityClass
#   Union: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2) | nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2)
# Creating UnionClass_MaxCardinalityClass
#   Union: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3) | nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3)
# Creating UnionClass_ExactCardinalityClass
#   Union: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1) | nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating UnionClass_DataSomeValueClass
#   Union: nested-expressions.simpleDataProperty1.some(<class 'int'>) | nested-expressions.simpleDataProperty1.some(<class 'int'>)
# Creating UnionClass_DataAllValueClass
#   Union: nested-expressions.simpleDataProperty2.only(<class 'str'>) | nested-expressions.simpleDataProperty2.only(<class 'str'>)
# Creating UnionClass_DataValueClass
#   Union: nested-expressions.simpleDataProperty3.value(1.0) | nested-expressions.simpleDataProperty3.value(1.0)
# Creating UnionClass_DataMinCardinalityClass
#   Union: nested-expressions.simpleDataProperty1.min(1, <class 'int'>) | nested-expressions.simpleDataProperty1.min(1, <class 'int'>)
# Creating UnionClass_DataMaxCardinalityClass
#   Union: nested-expressions.simpleDataProperty2.max(3, <class 'str'>) | nested-expressions.simpleDataProperty2.max(3, <class 'str'>)
# Creating UnionClass_DataExactCardinalityClass
# ...
# Creating AllValuesFromClass_DataMaxCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating AllValuesFromClass_DataExactCardinalityClass
#   Only: nested-expressions.simpleProperty2.only(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating ValueClass_EquivalentClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating ValueClass_SubClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.individual1)
# Creating ValueClass_UnionClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating ValueClass_IntersectionClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating ValueClass_ComplementClass
#   Value: nested-expressions.simpleProperty3.value(Not(nested-expressions.SimpleClass1))
# Creating ValueClass_OneOfClass
#   Value: nested-expressions.simpleProperty3.value(OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating ValueClass_SomeValuesFromClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating ValueClass_AllValuesFromClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating ValueClass_ValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating ValueClass_SelfClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.has_self())
# Creating ValueClass_MinCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating ValueClass_MaxCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating ValueClass_ExactCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating ValueClass_DataSomeValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating ValueClass_DataAllValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating ValueClass_DataValueClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty3.value(1.0))
# Creating ValueClass_DataMinCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating ValueClass_DataMaxCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating ValueClass_DataExactCardinalityClass
#   Value: nested-expressions.simpleProperty3.value(nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating SelfClass_EquivalentClass
#   Skipping SelfClass_EquivalentClass: Unsupported restriction type 117
# Creating SelfClass_SubClass
#   Skipping SelfClass_SubClass: Unsupported restriction type 117
# Creating SelfClass_UnionClass
#   Skipping SelfClass_UnionClass: Unsupported restriction type 117
# Creating SelfClass_IntersectionClass
#   Skipping SelfClass_IntersectionClass: Unsupported restriction type 117
# Creating SelfClass_ComplementClass
#   Skipping SelfClass_ComplementClass: Unsupported restriction type 117
# Creating SelfClass_OneOfClass
#   Skipping SelfClass_OneOfClass: Unsupported restriction type 117
# Creating SelfClass_SomeValuesFromClass
#   Skipping SelfClass_SomeValuesFromClass: Unsupported restriction type 117
# Creating SelfClass_AllValuesFromClass
#   Skipping SelfClass_AllValuesFromClass: Unsupported restriction type 117
# Creating SelfClass_ValueClass
#   Skipping SelfClass_ValueClass: Unsupported restriction type 117
# Creating SelfClass_SelfClass
#   Skipping SelfClass_SelfClass: Unsupported restriction type 117
# Creating SelfClass_MinCardinalityClass
#   Skipping SelfClass_MinCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_MaxCardinalityClass
#   Skipping SelfClass_MaxCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_ExactCardinalityClass
#   Skipping SelfClass_ExactCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataSomeValueClass
#   Skipping SelfClass_DataSomeValueClass: Unsupported restriction type 117
# Creating SelfClass_DataAllValueClass
#   Skipping SelfClass_DataAllValueClass: Unsupported restriction type 117
# Creating SelfClass_DataValueClass
#   Skipping SelfClass_DataValueClass: Unsupported restriction type 117
# Creating SelfClass_DataMinCardinalityClass
#   Skipping SelfClass_DataMinCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataMaxCardinalityClass
#   Skipping SelfClass_DataMaxCardinalityClass: Unsupported restriction type 117
# Creating SelfClass_DataExactCardinalityClass
#   Skipping SelfClass_DataExactCardinalityClass: Unsupported restriction type 117
# Creating MinCardinalityClass_EquivalentClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1)
# Creating MinCardinalityClass_SubClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SubClass)
# Creating MinCardinalityClass_UnionClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating MinCardinalityClass_IntersectionClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating MinCardinalityClass_ComplementClass
#   Min: nested-expressions.simpleProperty1.min(1, Not(nested-expressions.SimpleClass1))
# Creating MinCardinalityClass_OneOfClass
#   Min: nested-expressions.simpleProperty1.min(1, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating MinCardinalityClass_SomeValuesFromClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating MinCardinalityClass_AllValuesFromClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating MinCardinalityClass_ValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating MinCardinalityClass_SelfClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.has_self())
# Creating MinCardinalityClass_MinCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating MinCardinalityClass_MaxCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating MinCardinalityClass_ExactCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating MinCardinalityClass_DataSomeValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating MinCardinalityClass_DataAllValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating MinCardinalityClass_DataValueClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty3.value(1.0))
# Creating MinCardinalityClass_DataMinCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating MinCardinalityClass_DataMaxCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating MinCardinalityClass_DataExactCardinalityClass
#   Min: nested-expressions.simpleProperty1.min(1, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating MaxCardinalityClass_EquivalentClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1)
# Creating MaxCardinalityClass_SubClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SubClass)
# Creating MaxCardinalityClass_UnionClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating MaxCardinalityClass_IntersectionClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating MaxCardinalityClass_ComplementClass
#   Max: nested-expressions.simpleProperty2.max(3, Not(nested-expressions.SimpleClass1))
# Creating MaxCardinalityClass_OneOfClass
#   Max: nested-expressions.simpleProperty2.max(3, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating MaxCardinalityClass_SomeValuesFromClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating MaxCardinalityClass_AllValuesFromClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating MaxCardinalityClass_ValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating MaxCardinalityClass_SelfClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.has_self())
# Creating MaxCardinalityClass_MinCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating MaxCardinalityClass_MaxCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating MaxCardinalityClass_ExactCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating MaxCardinalityClass_DataSomeValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating MaxCardinalityClass_DataAllValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating MaxCardinalityClass_DataValueClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty3.value(1.0))
# Creating MaxCardinalityClass_DataMinCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating MaxCardinalityClass_DataMaxCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating MaxCardinalityClass_DataExactCardinalityClass
#   Max: nested-expressions.simpleProperty2.max(3, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Creating ExactCardinalityClass_EquivalentClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1)
# Creating ExactCardinalityClass_SubClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SubClass)
# Creating ExactCardinalityClass_UnionClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1 | nested-expressions.SimpleClass2)
# Creating ExactCardinalityClass_IntersectionClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1 & nested-expressions.SimpleClass2)
# Creating ExactCardinalityClass_ComplementClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, Not(nested-expressions.SimpleClass1))
# Creating ExactCardinalityClass_OneOfClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, OneOf([nested-expressions.individual1, nested-expressions.individual2, nested-expressions.individual3]))
# Creating ExactCardinalityClass_SomeValuesFromClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.some(nested-expressions.SimpleClass2))
# Creating ExactCardinalityClass_AllValuesFromClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty2.only(nested-expressions.SimpleClass3))
# Creating ExactCardinalityClass_ValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty3.value(nested-expressions.individual1))
# Creating ExactCardinalityClass_SelfClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.has_self())
# Creating ExactCardinalityClass_MinCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty1.min(1, nested-expressions.SimpleClass2))
# Creating ExactCardinalityClass_MaxCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty2.max(3, nested-expressions.SimpleClass3))
# Creating ExactCardinalityClass_ExactCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleProperty3.exactly(2, nested-expressions.SimpleClass1))
# Creating ExactCardinalityClass_DataSomeValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty1.some(<class 'int'>))
# Creating ExactCardinalityClass_DataAllValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# Creating ExactCardinalityClass_DataValueClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.value(1.0))
# Creating ExactCardinalityClass_DataMinCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# Creating ExactCardinalityClass_DataMaxCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# Creating ExactCardinalityClass_DataExactCardinalityClass
#   Exactly: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))
# Skipping combinations with DataSomeValueClass as first expression (data property class)
# Skipping combinations with DataAllValueClass as first expression (data property class)
# Skipping combinations with DataValueClass as first expression (data property class)
# Skipping combinations with DataMinCardinalityClass as first expression (data property class)
# Skipping combinations with DataMaxCardinalityClass as first expression (data property class)
# Skipping combinations with DataExactCardinalityClass as first expression (data property class)
#
# Total new class expressions generated: 176
# Ontology saved to nested_expressions.owl
#
# Sample of generated class expressions:
# ExactCardinalityClass_DataAllValueClass:
#   Equivalent to: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.only(<class 'str'>))
# ExactCardinalityClass_DataValueClass:
#   Equivalent to: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.value(1.0))
# ExactCardinalityClass_DataMinCardinalityClass:
#   Equivalent to: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty1.min(1, <class 'int'>))
# ExactCardinalityClass_DataMaxCardinalityClass:
#   Equivalent to: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty2.max(3, <class 'str'>))
# ExactCardinalityClass_DataExactCardinalityClass:
#   Equivalent to: nested-expressions.simpleProperty3.exactly(2, nested-expressions.simpleDataProperty3.exactly(2, <class 'float'>))

# %%
if :
    print(1)
# Out:
# 1
